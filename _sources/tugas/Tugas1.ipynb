# %% [markdown]
# # Tugas Pendata Mengambil Data Dari Database Yang Berbeda (Tugas 1)
#
# Nama :M. Hilmi Fajrul Alam
#
# NIM :210411100175
#
# Kelas :Penambangan Data-C

# %% [markdown]
# **Langkah Pertama**
#
# Langkah pertama yaitu membuat tabel di database postgresql

# %% [markdown]
# **Langkah Kedua**
#
# Selanjutnya yaitu membuat tabel di database mysql

# %% [markdown]
# **Langkah Ketiga**
#
# Selanjutnya buka aplikasi power bi, kemudian pilih menu Get data, pilih Database, kemudian pilih database yang ingin dibuka (Postgresql)

# %% [markdown]
# **Langkah Keempat**
#
# Kemudaian masukkan nama server dan databasenya. Kemudian pilih data yang akan diload.

# %% [markdown]
# **Langkah Kelima**
#
# Langkah selanjutnya adalah mengambil database yang berbeda, caranya klik menu Get data, pilih Database, kemudian pilih database yang ingin dibuka (Mysql)

# %% [markdown]
# **Langkah Keenam**
#
# Kemudaian masukkan nama server dan databasenya. Kemudian pilih data yang akan diload.

# %% [markdown]
# **Langkah Ketujuh**
#
# Kemudian klik menu Merge Queries. Selanjutnya pilih tabel mana saja yang ingin digabungkan. Lalu pilih metode penggabungan sesuai keinginan yautu inner join

# %% [markdown]
# **Langkah Kedelapan**
#
# Terakhir akan muncul tabel baru hasil dari penggabungan

# %% [markdown]
# ![Screenshot (72).png](data:image/png;base64,...)
